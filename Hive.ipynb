# %% [markdown]
# Represent CO_TO mappings using hive plots : http://egweb.bcgsc.ca/

# %%
# import libraries (including our short d3_lib script)
from IPython.core.display import HTML
import d3_lib
import json
from collections import OrderedDict

# %% [markdown]
# ### get the TO classes ordered by the category type

# %%
# %%script bash
# arq --results JSON --data https://raw.githubusercontent.com/Planteome/plant-trait-ontology/master/plant-trait-ontology.obo.owl '
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
# PREFIX oio: <http://www.geneontology.org/formats/oboInOwl#>
# PREFIX obo: <http://purl.obolibrary.org/obo/>
#
# SELECT distinct ?x ?xlabel ?o ?olabel ?topCat
# WHERE {
#     { select ?x ?xlabel
#         where {
#             ?x rdfs:subClassOf ?o .
#             ?x rdfs:label ?xlabel .
#             FILTER (!isBlank(?o))
#             FILTER (!regex(str(?o), "PATO_"))
#             }
#     }
#     ?x rdfs:subClassOf ?o .
#     ?o rdfs:label ?olabel .
#     ?o rdfs:subClassOf* ?topCat .
#     ?topCat rdfs:subClassOf <http://purl.obolibrary.org/obo/TO_0000387> .
# }
# order by ?topCat ?xlabel
# ' > data/to.json

# %% [markdown]
# # prepare the data for the hive plot

# %%
graph = {"nodes": [], "links": []}

# %% [markdown]
# ### TO classes

# %%
with open('data/to.json') as data_file:    
    data = json.load(data_file)
    
    list = data["results"]["bindings"]
    
    temp = OrderedDict()
    
    #force plant trait to be the first node
    #graph["nodes"].append( {"x": 0, "y": y/100, "name": "plant trait", "id": "http://purl.obolibrary.org/obo/TO_0000387" } )
    #y+=1
    for entry in list:
        temp[entry["x"]["value"]]={"x": 0, "name": entry["xlabel"]["value"], "id":entry["x"]["value"], "type":entry["topCat"]["value"] }
        #temp.append( {"x": 0, "name": entry["xlabel"]["value"], "id":entry["x"]["value"], "type":entry["topCat"]["value"] } )
    
    print(len(temp))
# Out:
# 1371

# %% [markdown]
# ### CO classes

# %%
with open('data/co.json') as co_file:    
    co = json.load(co_file)
    ##position on the axes
    y1 = 1
    y2 = 1
    ## will be used to keep TO classes that have a mapping to CO
    tab = []
    
    #create the nodes
    for entry in co:
        del entry['group']  
        del entry['value']
        if "CO_341" in entry["id"]:
            entry["x"] = 1
            entry["y"] = y1/100
            y1+=1
            graph["nodes"].append(entry)
            tab.append(entry["id"])
        if "CO_336" in entry["id"]:
            entry["x"] = 1
            entry["y"] = y1/100
            y1+=1
            graph["nodes"].append(entry)
            tab.append(entry["id"])
        if "CO_339" in entry["id"]:
            entry["x"] = 1
            entry["y"] = y1/100
            y1+=1
            graph["nodes"].append(entry)
            tab.append(entry["id"])
        if "CO_320" in entry["id"]:
            entry["x"] = 1
            entry["y"] = y1/100
            y1+=1
            graph["nodes"].append(entry)
            tab.append(entry["id"])
        if "CO_322" in entry["id"]:
            entry["x"] = 2
            entry["y"] = y2/100
            y2+=1
            graph["nodes"].append(entry)
            tab.append(entry["id"])
        if "CO_321" in entry["id"]:
            entry["x"] = 2
            entry["y"] = y2/100
            y2+=1
            graph["nodes"].append(entry)
            tab.append(entry["id"])
        if "CO_334" in entry["id"]:
            entry["x"] = 2
            entry["y"] = y2/100
            y2+=1
            graph["nodes"].append(entry)
            tab.append(entry["id"])
        elif "CO_331" in entry["id"]:
            entry["x"] = 2
            entry["y"] = y2/100
            y2+=1
            graph["nodes"].append(entry)
            tab.append(entry["id"])
            
print(len(graph["nodes"]))
# Out:
# 1145

# %%
### remove the TO classes that don't map any CO class
with open('data/COTOMappings.json') as mapping_file:    
    coto = json.load(mapping_file)
    
    ##for the position on the axis
    y = 1
    tab1 = [] 
    for cl in coto:
        if(cl["x"] in tab):
            tab1.append(cl["o"]);
 
    for e,v in temp.items():
        if(e in tab1):
            v["y"]=y/100
            y+=1
            graph["nodes"].append(v)
                
                
    print(len(graph["nodes"]))
# Out:
# 1529

# %% [markdown]
# ### add mappings

# %%
with open('data/COTOMappings.json') as data_file:    
    mapping = json.load(data_file)
    
    #create the links
    for entry in mapping:
        x=0; 
        o=0; 
        for e in graph["nodes"]:
            if e["id"] == entry["x"]:
                x=e
            elif e["id"] == entry["o"]:
                o=e
                   
        if(x!=0 and o!=0):
            graph["links"].append( {"source": x, "target": o} )
            
print(len(graph["links"]))
# Out:
# 1123

# %%
with open('data/hive.json', 'w') as outfile:
    json.dump(graph, outfile)

# %% [markdown]
# ### hive plot

# %%
# visualize as force-directed graph in D3
HTML(d3_lib.set_styles(['hive']) + 
'<script src="lib/d3/d3.min.js"></script>' + 
     '<script src="lib/d3.hive.min.js"></script>' + 
      d3_lib.draw_graph('hive', {'data': graph}) )
# Out:
# <style>
# .axis {
#   stroke: #000;
#   stroke-width: 1.5px;
# }
#
# .node circle {
#   stroke: #000;
# }
#
# .link {
#   fill: none;
#   stroke: #999;
#   stroke-width: 1.5px;
#   stroke-opacity: .3;
# }
#
# .link.active {
#   stroke: red;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
# .node.active {
#   stroke: red;
#   stroke-width: 3px;
# }</style><script src="lib/d3/d3.min.js"></script><script src="lib/d3.hive.min.js"></script>
#
#                 <div id='maindiv2264743606'></div>
#
#                 <script>
#                     var width = 960,
#     height = 500,
#     innerRadius = 40,
#     outerRadius = 560;
#
# var angle = d3.scale.ordinal().domain(d3.range(4)).rangePoints([0, 2 * Math.PI]),
#     radius = d3.scale.linear().range([innerRadius, outerRadius]),
#     color = d3.scale.category10().domain(d3.range(20));
#
# var graph = {'links': [{'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000148', 'x': 0, 'y': 2.82, 'type': 'http://purl.obolibrary.org/obo/TO_0000164', 'name': 'viral disease resistance'}, 'source': {'id': 'CO_341:0000057', 'x': 1, 'y': 0.01, 'name': 'Sterility mosaic incidence'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000056', 'x': 0, 'y': 1.7, 'type': 'http://purl.obolibrary.org/obo/TO_0000017', 'name': 'stem color'}, 'source': {'id': 'CO_341:0000081', 'x': 1, 'y': 0.02, 'name': 'Stem color'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000168', 'x': 0, 'y': 2.08, 'type': 'http://purl.obolibrary.org/obo/TO_0000164', 'name': 'abiotic stress trait'}, 'source': {'id': 'CO_341:0000151', 'x': 1, 'y': 0.03, 'name': 'Soil salinity stress susceptibility'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000168', 'x': 0, 'y': 2.08, 'type': 'http://purl.obolibrary.org/obo/TO_0000164', 'name': 'abiotic stress trait'}, 'source': {'id': 'CO_341:0000152', 'x': 1, 'y': 0.04, 'name': 'Soil acidity stress susceptibility'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000250', 'x': 0, 'y': 2.07, 'type': 'http://purl.obolibrary.org/obo/TO_0000133', 'name': 'vigor related trait'}, 'source': {'id': 'CO_341:0000135', 'x': 1, 'y': 0.05, 'name': 'Seedling vigour'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000486', 'x': 0, 'y': 1.52, 'type': 'http://purl.obolibrary.org/obo/TO_0000017', 'name': 'seed color'}, 'source': {'id': 'CO_341:0000078', 'x': 1, 'y': 0.06, 'name': 'Seed base colour'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000905', 'x': 0, 'y': 3.57, 'type': 'http://purl.obolibrary.org/obo/TO_0000371', 'name': 'seed yield trait'}, 'source': {'id': 'CO_341:0000126', 'x': 1, 'y': 0.07, 'name': 'Seed yield'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002746', 'x': 0, 'y': 0.51, 'type': 'http://purl.obolibrary.org/obo/TO_0000017', 'name': 'fruit weight'}, 'source': {'id': 'CO_341:0000123', 'x': 1, 'y': 0.08, 'name': 'Grain weight per plant'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002746', 'x': 0, 'y': 0.51, 'type': 'http://purl.obolibrary.org/obo/TO_0000017', 'name': 'fruit weight'}, 'source': {'id': 'CO_341:0000120', 'x': 1, 'y': 0.09, 'name': 'Grain weight per plot'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000269', 'x': 0, 'y': 0.01, 'type': 'http://purl.obolibrary.org/obo/TO_0000017', 'name': '100-seed weight'}, 'source': {'id': 'CO_341:0000117', 'x': 1, 'y': 0.1, 'name': 'Weight of 100 seeds'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000667', 'x': 0, 'y': 3.68, 'type': 'http://purl.obolibrary.org/obo/TO_0000597', 'name': 'cooking or brewing quality'}, 'source': {'id': 'CO_341:0000114', 'x': 1, 'y': 0.11, 'name': 'Cooking quality of seed'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000931', 'x': 0, 'y': 3.83, 'type': 'http://purl.obolibrary.org/obo/TO_0000597', 'name': 'seed quality trait'}, 'source': {'id': 'CO_341:0000108', 'x': 1, 'y': 0.12, 'name': 'Seed milling fraction'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000490', 'x': 0, 'y': 3.82, 'type': 'http://purl.obolibrary.org/obo/TO_0000597', 'name': 'seed protein composition trait'}, 'source': {'id': 'CO_341:0000105', 'x': 1, 'y': 0.13, 'name': 'Seed protein content'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000202', 'x': 0, 'y': 2.04, 'type': 'http://purl.obolibrary.org/obo/TO_0000597', 'name': 'germination ratio'}, 'source': {'id': 'CO_341:0000075', 'x': 1, 'y': 0.14, 'name': 'Seed germination'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000228', 'x': 0, 'y': 3.78, 'type': 'http://purl.obolibrary.org/obo/TO_0000597', 'name': 'moisture content related trait'}, 'source': {'id': 'CO_341:0000060', 'x': 1, 'y': 0.15, 'name': 'Seed moisture content'}}, {'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000184', 'x': 0, 'y': 1.53, 'type': 'http://purl.obolibrary.org/obo/TO_0000017', 'name': 'seed mo ...

# %%
graph
# Out:
# {'links': [{'source': {'id': 'CO_341:0000057',
#     'name': 'Sterility mosaic incidence',
#     'x': 1,
#     'y': 0.01},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000148',
#     'name': 'viral disease resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.82}},
#   {'source': {'id': 'CO_341:0000081', 'name': 'Stem color', 'x': 1, 'y': 0.02},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000056',
#     'name': 'stem color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.7}},
#   {'source': {'id': 'CO_341:0000151',
#     'name': 'Soil salinity stress susceptibility',
#     'x': 1,
#     'y': 0.03},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000168',
#     'name': 'abiotic stress trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.08}},
#   {'source': {'id': 'CO_341:0000152',
#     'name': 'Soil acidity stress susceptibility',
#     'x': 1,
#     'y': 0.04},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000168',
#     'name': 'abiotic stress trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.08}},
#   {'source': {'id': 'CO_341:0000135',
#     'name': 'Seedling vigour',
#     'x': 1,
#     'y': 0.05},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000250',
#     'name': 'vigor related trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000133',
#     'x': 0,
#     'y': 2.07}},
#   {'source': {'id': 'CO_341:0000078',
#     'name': 'Seed base colour',
#     'x': 1,
#     'y': 0.06},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000486',
#     'name': 'seed color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.52}},
#   {'source': {'id': 'CO_341:0000126', 'name': 'Seed yield', 'x': 1, 'y': 0.07},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000905',
#     'name': 'seed yield trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000371',
#     'x': 0,
#     'y': 3.57}},
#   {'source': {'id': 'CO_341:0000123',
#     'name': 'Grain weight per plant',
#     'x': 1,
#     'y': 0.08},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002746',
#     'name': 'fruit weight',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.51}},
#   {'source': {'id': 'CO_341:0000120',
#     'name': 'Grain weight per plot',
#     'x': 1,
#     'y': 0.09},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002746',
#     'name': 'fruit weight',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.51}},
#   {'source': {'id': 'CO_341:0000117',
#     'name': 'Weight of 100 seeds',
#     'x': 1,
#     'y': 0.1},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000269',
#     'name': '100-seed weight',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.01}},
#   {'source': {'id': 'CO_341:0000114',
#     'name': 'Cooking quality of seed',
#     'x': 1,
#     'y': 0.11},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000667',
#     'name': 'cooking or brewing quality',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.68}},
#   {'source': {'id': 'CO_341:0000108',
#     'name': 'Seed milling fraction',
#     'x': 1,
#     'y': 0.12},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000931',
#     'name': 'seed quality trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.83}},
#   {'source': {'id': 'CO_341:0000105',
#     'name': 'Seed protein content',
#     'x': 1,
#     'y': 0.13},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000490',
#     'name': 'seed protein composition trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.82}},
#   {'source': {'id': 'CO_341:0000075',
#     'name': 'Seed germination',
#     'x': 1,
#     'y': 0.14},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000202',
#     'name': 'germination ratio',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 2.04}},
#   {'source': {'id': 'CO_341:0000060',
#     'name': 'Seed moisture content',
#     'x': 1,
#     'y': 0.15},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000228',
#     'name': 'moisture content related trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.78}},
#   {'source': {'id': 'CO_341:0000042',
#     'name': 'Seeds per plant',
#     'x': 1,
#     'y': 0.16},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000184',
#     'name': 'seed morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.53}},
#   {'source': {'id': 'CO_341:0000039',
#     'name': 'Seeds per pod',
#     'x': 1,
#     'y': 0.17},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000445',
#     'name': 'fruit seed number',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.49}},
#   {'source': {'id': 'CO_341:0000030',
#     'name': 'Seed weight',
#     'x': 1,
#     'y': 0.18},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000181',
#     'name': 'seed weight',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.55}},
#   {'source': {'id': 'CO_341:0000018',
#     'name': 'Number of secondary branches',
#     'x': 1,
#     'y': 0.19},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000557',
#     'name': 'secondary branch number',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 1.46}},
#   {'source': {'id': 'CO_341:0000069',
#     'name': 'Radicle length',
#     'x': 1,
#     'y': 0.2},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000227',
#     'name': 'root length',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.38}},
#   {'source': {'id': 'CO_341:0000012',
#     'name': 'Number of productive branches',
#     'x': 1,
#     'y': 0.21},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000547',
#     'name': 'primary branch number',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 1.34}},
#   {'source': {'id': 'CO_341:0000015',
#     'name': 'Number of primary branches',
#     'x': 1,
#     'y': 0.22},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000547',
#     'name': 'primary branch number',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 1.34}},
#   {'source': {'id': 'CO_341:0000153',
#     'name': 'Pod wasp susceptibility',
#     'x': 1,
#     'y': 0.23},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000261',
#     'name': 'insect damage resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.45}},
#   {'source': {'id': 'CO_341:0000154',
#     'name': 'Pod fly susceptibility',
#     'x': 1,
#     'y': 0.24},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000261',
#     'name': 'insect damage resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.45}},
#   {'source': {'id': 'CO_341:0000155',
#     'name': 'Pod borers susceptibility',
#     'x': 1,
#     'y': 0.25},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000261',
#     'name': 'insect damage resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.45}},
#   {'source': {'id': 'CO_341:0000141', 'name': 'Pod length', 'x': 1, 'y': 0.26},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002626',
#     'name': 'fruit length',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.45}},
#   {'source': {'id': 'CO_341:0000102', 'name': 'Pod size', 'x': 1, 'y': 0.27},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002625',
#     'name': 'fruit size',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.5}},
#   {'source': {'id': 'CO_341:0000099', 'name': 'Pod wax', 'x': 1, 'y': 0.28},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002629',
#     'name': 'fruit morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.46}},
#   {'source': {'id': 'CO_341:0000096',
#     'name': 'Pod pubescence',
#     'x': 1,
#     'y': 0.29},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000851',
#     'name': 'fruit hairiness',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.44}},
#   {'source': {'id': 'CO_341:0000093', 'name': 'Pod color', 'x': 1, 'y': 0.3},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002617',
#     'name': 'fruit color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.43}},
#   {'source': {'id': 'CO_341:0000036',
#     'name': 'Pods per plant',
#     'x': 1,
#     'y': 0.31},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000894',
#     'name': 'fruit number trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.47}},
#   {'source': {'id': 'CO_341:0000033',
#     'name': 'Pods per cluster',
#     'x': 1,
#     'y': 0.32},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000894',
#     'name': 'fruit number trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.47}},
#   {'source': {'id': 'CO_341:0000072',
#     'name': 'Plumule length',
#     'x': 1,
#     'y': 0.33},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000739',
#     'name': 'shoot axis morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.6}},
#   {'source': {'id': 'CO_341:0000147',
#     'name': 'Plant Fertility',
#     'x': 1,
#     'y': 0.34},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000420',
#     'name': 'fertility related trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000392',
#     'x': 0,
#     'y': 3.6}},
#   {'source': {'id': 'CO_341:0000138',
#     'name': 'Days to first flower',
#     'x': 1,
#     'y': 0.35},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000344',
#     'name': 'days to flowering trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.29}},
#   {'source': {'id': 'CO_341:0000132',
#     'name': 'Plant vigour',
#     'x': 1,
#     'y': 0.36},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000250',
#     'name': 'vigor related trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000133',
#     'x': 0,
#     'y': 2.07}},
#   {'source': {'id': 'CO_341:0000129',
#     'name': 'Plant senescence',
#     'x': 1,
#     'y': 0.37},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000928',
#     'name': 'plant structure growth and development trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.4}},
#   {'source': {'id': 'CO_341:0000063',
#     'name': 'Harvest index',
#     'x': 1,
#     'y': 0.38},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000128',
#     'name': 'harvest index',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000371',
#     'x': 0,
#     'y': 3.52}},
#   {'source': {'id': 'CO_341:0000027',
#     'name': 'Pod bearing length',
#     'x': 1,
#     'y': 0.39},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002626',
#     'name': 'fruit length',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.45}},
#   {'source': {'id': 'CO_341:0000021',
#     'name': 'Plant height',
#     'x': 1,
#     'y': 0.4},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000207',
#     'name': 'plant height',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.28}},
#   {'source': {'id': 'CO_341:0000009',
#     'name': 'Days to 75 % maturity',
#     'x': 1,
#     'y': 0.41},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000469',
#     'name': 'days to maturity',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.32}},
#   {'source': {'id': 'CO_341:0000006',
#     'name': 'Days to 50 % flowering',
#     'x': 1,
#     'y': 0.42},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000344',
#     'name': 'days to flowering trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.29}},
#   {'source': {'id': 'CO_341:0000003',
#     'name': 'Maturity group',
#     'x': 1,
#     'y': 0.43},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000344',
#     'name': 'days to flowering trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.29}},
#   {'source': {'id': 'CO_341:0000000',
#     'name': 'Flowering pattern',
#     'x': 1,
#     'y': 0.44},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002616',
#     'name': 'flowering time trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.35}},
#   {'source': {'id': 'CO_341:0000156',
#     'name': 'Phytophthora blight disease susceptibility',
#     'x': 1,
#     'y': 0.45},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000439',
#     'name': 'fungal disease resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.39}},
#   {'source': {'id': 'CO_341:0000157',
#     'name': 'Nematodes susceptibility',
#     'x': 1,
#     'y': 0.46},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000384',
#     'name': 'nematode damage resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.56}},
#   {'source': {'id': 'CO_341:0000158',
#     'name': 'Low temperature stress susceptibility',
#     'x': 1,
#     'y': 0.47},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000303',
#     'name': 'cold tolerance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.3}},
#   {'source': {'id': 'CO_341:0000159',
#     'name': 'Leaf tier susceptibility',
#     'x': 1,
#     'y': 0.48},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000261',
#     'name': 'insect damage resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.45}},
#   {'source': {'id': 'CO_341:0000087',
#     'name': 'Leaf pubescence',
#     'x': 1,
#     'y': 0.49},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002722',
#     'name': 'leaf pubescence',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.9}},
#   {'source': {'id': 'CO_341:0000084', 'name': 'Leaf shape', 'x': 1, 'y': 0.5},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000492',
#     'name': 'leaf shape',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.92}},
#   {'source': {'id': 'CO_341:0000066',
#     'name': 'Leaf chlorophyll content',
#     'x': 1,
#     'y': 0.51},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0012002',
#     'name': 'leaf chlorophyll content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.07}},
#   {'source': {'id': 'CO_341:0000160',
#     'name': 'High temperature stress susceptibility',
#     'x': 1,
#     'y': 0.52},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000259',
#     'name': 'heat tolerance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.43}},
#   {'source': {'id': 'CO_341:0000054',
#     'name': 'Fusarium wilt Incidence',
#     'x': 1,
#     'y': 0.53},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000439',
#     'name': 'fungal disease resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.39}},
#   {'source': {'id': 'CO_341:0000090',
#     'name': 'Flower color',
#     'x': 1,
#     'y': 0.54},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000537',
#     'name': 'flower color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.38}},
#   {'source': {'id': 'CO_341:0000161',
#     'name': 'Drought stress susceptibility',
#     'x': 1,
#     'y': 0.55},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000188',
#     'name': 'drought sensitivity',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.35}},
#   {'source': {'id': 'CO_341:0000111',
#     'name': 'Cooking quality of dhal',
#     'x': 1,
#     'y': 0.56},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000667',
#     'name': 'cooking or brewing quality',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.68}},
#   {'source': {'id': 'CO_341:0000144',
#     'name': 'Number of clusters',
#     'x': 1,
#     'y': 0.57},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000920',
#     'name': 'infructescence morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.73}},
#   {'source': {'id': 'CO_341:0000162',
#     'name': 'Alternaria blight disease susceptibility',
#     'x': 1,
#     'y': 0.58},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000439',
#     'name': 'fungal disease resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.39}},
#   {'source': {'id': 'CO_336:0000000',
#     'name': 'Flowering time',
#     'x': 1,
#     'y': 0.59},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002616',
#     'name': 'flowering time trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.35}},
#   {'source': {'id': 'CO_336:0000003',
#     'name': 'Bacterial Pustule',
#     'x': 1,
#     'y': 0.6},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000315',
#     'name': 'bacterial disease resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.16}},
#   {'source': {'id': 'CO_336:0000006',
#     'name': 'Soybean rust',
#     'x': 1,
#     'y': 0.61},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000439',
#     'name': 'fungal disease resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.39}},
#   {'source': {'id': 'CO_336:0000009',
#     'name': 'Soybean Mosaic Virus',
#     'x': 1,
#     'y': 0.62},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000148',
#     'name': 'viral disease resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.82}},
#   {'source': {'id': 'CO_336:0000012',
#     'name': 'Frogeye leafspot',
#     'x': 1,
#     'y': 0.63},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000439',
#     'name': 'fungal disease resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.39}},
#   {'source': {'id': 'CO_336:0000015', 'name': 'Nodulation', 'x': 1, 'y': 0.64},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000898',
#     'name': 'root nodule morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.4}},
#   {'source': {'id': 'CO_336:0000018',
#     'name': 'Root knot nematode',
#     'x': 1,
#     'y': 0.65},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000384',
#     'name': 'nematode damage resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.56}},
#   {'source': {'id': 'CO_336:0000021',
#     'name': 'Maturity time',
#     'x': 1,
#     'y': 0.66},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000469',
#     'name': 'days to maturity',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.32}},
#   {'source': {'id': 'CO_336:0000024',
#     'name': 'Height of lowest pods',
#     'x': 1,
#     'y': 0.67},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_1000011',
#     'name': 'fruit position',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.48}},
#   {'source': {'id': 'CO_336:0000027',
#     'name': 'Plant height',
#     'x': 1,
#     'y': 0.68},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000207',
#     'name': 'plant height',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.28}},
#   {'source': {'id': 'CO_336:0000030', 'name': 'Lodging', 'x': 1, 'y': 0.69},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000068',
#     'name': 'lodging incidence',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.53}},
#   {'source': {'id': 'CO_336:0000036', 'name': 'Seed yield', 'x': 1, 'y': 0.7},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000905',
#     'name': 'seed yield trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000371',
#     'x': 0,
#     'y': 3.57}},
#   {'source': {'id': 'CO_336:0000042',
#     'name': 'Early shattering',
#     'x': 1,
#     'y': 0.72},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000473',
#     'name': 'grain shattering',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.75}},
#   {'source': {'id': 'CO_336:0000248',
#     'name': 'Pod shattering',
#     'x': 1,
#     'y': 0.73},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000473',
#     'name': 'grain shattering',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.75}},
#   {'source': {'id': 'CO_336:0000048',
#     'name': 'Seed oil content',
#     'x': 1,
#     'y': 0.74},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000604',
#     'name': 'fat and essential oil content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.03}},
#   {'source': {'id': 'CO_336:0000051',
#     'name': 'Seed protein content',
#     'x': 1,
#     'y': 0.75},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000490',
#     'name': 'seed protein composition trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.82}},
#   {'source': {'id': 'CO_336:0000054',
#     'name': 'Reaction to Aphis glycines',
#     'x': 1,
#     'y': 0.76},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0006067',
#     'name': 'aphid resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.13}},
#   {'source': {'id': 'CO_336:0000057',
#     'name': 'Plant branching',
#     'x': 1,
#     'y': 0.77},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000052',
#     'name': 'primary branching of inflorescence',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 1.35}},
#   {'source': {'id': 'CO_336:0000060',
#     'name': 'Reproductive period',
#     'x': 1,
#     'y': 0.78},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000933',
#     'name': 'plant phenological trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.39}},
#   {'source': {'id': 'CO_336:0000063',
#     'name': 'Flower color',
#     'x': 1,
#     'y': 0.79},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000537',
#     'name': 'flower color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.38}},
#   {'source': {'id': 'CO_336:0000066', 'name': 'Pod length', 'x': 1, 'y': 0.8},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002626',
#     'name': 'fruit length',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.45}},
#   {'source': {'id': 'CO_336:0000069',
#     'name': 'Twining date',
#     'x': 1,
#     'y': 0.81},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000933',
#     'name': 'plant phenological trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.39}},
#   {'source': {'id': 'CO_336:0000072',
#     'name': 'Flooding tolerance',
#     'x': 1,
#     'y': 0.82},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000114',
#     'name': 'flooding related trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.38}},
#   {'source': {'id': 'CO_336:0000075', 'name': 'Chlorosis', 'x': 1, 'y': 0.83},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000480',
#     'name': 'nutrient sensitivity',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.57}},
#   {'source': {'id': 'CO_336:0000078',
#     'name': 'Drought Tolerance',
#     'x': 1,
#     'y': 0.84},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000276',
#     'name': 'drought tolerance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.36}},
#   {'source': {'id': 'CO_336:0000081',
#     'name': 'Herbicide sensitivity',
#     'x': 1,
#     'y': 0.85},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000058',
#     'name': 'herbicide sensitivity',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.44}},
#   {'source': {'id': 'CO_336:0000084',
#     'name': 'Seed oil/protein content',
#     'x': 1,
#     'y': 0.86},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000604',
#     'name': 'fat and essential oil content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.03}},
#   {'source': {'id': 'CO_336:0000087',
#     'name': 'Seed filling period',
#     'x': 1,
#     'y': 0.87},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002661',
#     'name': 'seed maturation',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.42}},
#   {'source': {'id': 'CO_336:0000090', 'name': 'Pod color', 'x': 1, 'y': 0.88},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002617',
#     'name': 'fruit color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.43}},
#   {'source': {'id': 'CO_336:0000093',
#     'name': 'Hilum color',
#     'x': 1,
#     'y': 0.89},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000968',
#     'name': 'hilum color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.64}},
#   {'source': {'id': 'CO_336:0000096',
#     'name': 'Seed quality',
#     'x': 1,
#     'y': 0.9},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000931',
#     'name': 'seed quality trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.83}},
#   {'source': {'id': 'CO_336:0000099',
#     'name': 'Cold stress resistance',
#     'x': 1,
#     'y': 0.91},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000303',
#     'name': 'cold tolerance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.3}},
#   {'source': {'id': 'CO_336:0000102',
#     'name': 'Heat stress resistance',
#     'x': 1,
#     'y': 0.92},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000259',
#     'name': 'heat tolerance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.43}},
#   {'source': {'id': 'CO_336:0000105',
#     'name': 'Seed linoleic acid content',
#     'x': 1,
#     'y': 0.93},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0005001',
#     'name': 'linoleic acid content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.08}},
#   {'source': {'id': 'CO_336:0000108',
#     'name': 'Seed linolenic acid content',
#     'x': 1,
#     'y': 0.94},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0005004',
#     'name': 'omega-3 fatty acid content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.13}},
#   {'source': {'id': 'CO_336:0000111',
#     'name': 'Seed palmitic acid content',
#     'x': 1,
#     'y': 0.95},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000604',
#     'name': 'fat and essential oil content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.03}},
#   {'source': {'id': 'CO_336:0000114',
#     'name': 'Seed oleic acid content',
#     'x': 1,
#     'y': 0.96},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0005002',
#     'name': 'oleic acid content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.12}},
#   {'source': {'id': 'CO_336:0000117',
#     'name': 'Seed methionine content',
#     'x': 1,
#     'y': 0.97},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002673',
#     'name': 'amino acid content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 2.94}},
#   {'source': {'id': 'CO_336:0000120',
#     'name': 'Seed stearic acid content',
#     'x': 1,
#     'y': 0.98},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0005003',
#     'name': 'stearic acid content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.19}},
#   {'source': {'id': 'CO_336:0000123',
#     'name': 'Stem termination type',
#     'x': 1,
#     'y': 0.99},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0006017',
#     'name': 'meristem identity',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.38}},
#   {'source': {'id': 'CO_336:0000126',
#     'name': 'Beet armyworm',
#     'x': 1,
#     'y': 1.0},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000273',
#     'name': 'armyworm resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.14}},
#   {'source': {'id': 'CO_336:0000129',
#     'name': 'Defoliation',
#     'x': 1,
#     'y': 1.01},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000261',
#     'name': 'insect damage resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.45}},
#   {'source': {'id': 'CO_336:0000132',
#     'name': 'Late Shattering Score',
#     'x': 1,
#     'y': 1.02},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000473',
#     'name': 'grain shattering',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.75}},
#   {'source': {'id': 'CO_336:0000135',
#     'name': 'Pubescence Color',
#     'x': 1,
#     'y': 1.03},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000911',
#     'name': 'trichome morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.99}},
#   {'source': {'id': 'CO_336:0000141',
#     'name': 'Maturity group',
#     'x': 1,
#     'y': 1.04},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000653',
#     'name': 'seed growth and development trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.41}},
#   {'source': {'id': 'CO_336:0000144',
#     'name': 'Seed coat mottling',
#     'x': 1,
#     'y': 1.05},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0020017',
#     'name': 'seed coat spotted',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.51}},
#   {'source': {'id': 'CO_336:0000147',
#     'name': 'Seed lysine content',
#     'x': 1,
#     'y': 1.06},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002673',
#     'name': 'amino acid content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 2.94}},
#   {'source': {'id': 'CO_336:0000150',
#     'name': 'Leaf chlorophyll content',
#     'x': 1,
#     'y': 1.07},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0012002',
#     'name': 'leaf chlorophyll content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.07}},
#   {'source': {'id': 'CO_336:0000153',
#     'name': 'Seed isoflavone content',
#     'x': 1,
#     'y': 1.08},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000281',
#     'name': 'metabolite content trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.1}},
#   {'source': {'id': 'CO_336:0000156',
#     'name': 'Germination time',
#     'x': 1,
#     'y': 1.09},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0006061',
#     'name': 'days to germinate',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.3}},
#   {'source': {'id': 'CO_336:0000159',
#     'name': 'Flower number',
#     'x': 1,
#     'y': 1.1},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002736',
#     'name': 'flower number trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.4}},
#   {'source': {'id': 'CO_336:0000162',
#     'name': 'Canopy height',
#     'x': 1,
#     'y': 1.11},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000207',
#     'name': 'plant height',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.28}},
#   {'source': {'id': 'CO_336:0000165',
#     'name': 'First flower',
#     'x': 1,
#     'y': 1.12},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002616',
#     'name': 'flowering time trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.35}},
#   {'source': {'id': 'CO_336:0000168',
#     'name': 'Nodule number',
#     'x': 1,
#     'y': 1.13},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000900',
#     'name': 'root nodule number',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.41}},
#   {'source': {'id': 'CO_336:0000171',
#     'name': 'Pod Maturity Date',
#     'x': 1,
#     'y': 1.14},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000469',
#     'name': 'days to maturity',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.32}},
#   {'source': {'id': 'CO_336:0000174',
#     'name': 'R8 Full Maturity',
#     'x': 1,
#     'y': 1.15},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000469',
#     'name': 'days to maturity',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000357',
#     'x': 0,
#     'y': 3.32}},
#   {'source': {'id': 'CO_336:0000177',
#     'name': 'Root nodule weight',
#     'x': 1,
#     'y': 1.16},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000899',
#     'name': 'root nodule weight',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.42}},
#   {'source': {'id': 'CO_336:0000180',
#     'name': 'Primary root shape',
#     'x': 1,
#     'y': 1.17},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002710',
#     'name': 'root shape',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.44}},
#   {'source': {'id': 'CO_336:0000183',
#     'name': 'Primary root size',
#     'x': 1,
#     'y': 1.18},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000043',
#     'name': 'root morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.39}},
#   {'source': {'id': 'CO_336:0000186',
#     'name': 'Leaf number',
#     'x': 1,
#     'y': 1.19},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000241',
#     'name': 'leaf number',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.89}},
#   {'source': {'id': 'CO_336:0000189',
#     'name': 'Main stem diameter',
#     'x': 1,
#     'y': 1.2},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0020083',
#     'name': 'stem diameter',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.72}},
#   {'source': {'id': 'CO_336:0000192',
#     'name': 'Fiber content',
#     'x': 1,
#     'y': 1.21},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002642',
#     'name': 'dietary fiber related trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.69}},
#   {'source': {'id': 'CO_336:0000195',
#     'name': 'Seed moisture content',
#     'x': 1,
#     'y': 1.22},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000228',
#     'name': 'moisture content related trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.78}},
#   {'source': {'id': 'CO_336:0000198',
#     'name': 'Seed Sucrose content',
#     'x': 1,
#     'y': 1.23},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000328',
#     'name': 'sucrose content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.2}},
#   {'source': {'id': 'CO_336:0000201',
#     'name': 'Downy mildew',
#     'x': 1,
#     'y': 1.24},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000439',
#     'name': 'fungal disease resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.39}},
#   {'source': {'id': 'CO_336:0000204',
#     'name': 'Soybean anthracnose',
#     'x': 1,
#     'y': 1.25},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000439',
#     'name': 'fungal disease resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.39}},
#   {'source': {'id': 'CO_336:0000207',
#     'name': 'Lateral root size',
#     'x': 1,
#     'y': 1.26},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000043',
#     'name': 'root morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.39}},
#   {'source': {'id': 'CO_336:0000210',
#     'name': 'Lateral root shape',
#     'x': 1,
#     'y': 1.27},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002710',
#     'name': 'root shape',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.44}},
#   {'source': {'id': 'CO_336:0000213',
#     'name': 'Seed starchyose content',
#     'x': 1,
#     'y': 1.28},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0006007',
#     'name': 'polysaccharide content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.14}},
#   {'source': {'id': 'CO_336:0000216',
#     'name': 'Seed Raffinose content',
#     'x': 1,
#     'y': 1.29},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0006004',
#     'name': 'raffinose content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.17}},
#   {'source': {'id': 'CO_336:0000219',
#     'name': 'Leaflet shape',
#     'x': 1,
#     'y': 1.3},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000754',
#     'name': 'cardinal organ part morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.18}},
#   {'source': {'id': 'CO_336:0000222',
#     'name': 'Pubescence form',
#     'x': 1,
#     'y': 1.31},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000911',
#     'name': 'trichome morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.99}},
#   {'source': {'id': 'CO_336:0000346',
#     'name': 'Pubescence form on leaflet',
#     'x': 1,
#     'y': 1.32},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000911',
#     'name': 'trichome morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.99}},
#   {'source': {'id': 'CO_336:0000225',
#     'name': 'Pubescence tip type',
#     'x': 1,
#     'y': 1.33},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000911',
#     'name': 'trichome morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.99}},
#   {'source': {'id': 'CO_336:0000228',
#     'name': 'Flower form',
#     'x': 1,
#     'y': 1.34},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000881',
#     'name': 'flower type',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.42}},
#   {'source': {'id': 'CO_336:0000231',
#     'name': 'Pubescence presence',
#     'x': 1,
#     'y': 1.35},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000911',
#     'name': 'trichome morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.99}},
#   {'source': {'id': 'CO_336:0000236', 'name': 'Pod number', 'x': 1, 'y': 1.36},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000894',
#     'name': 'fruit number trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.47}},
#   {'source': {'id': 'CO_336:0000237',
#     'name': 'Number of seeds',
#     'x': 1,
#     'y': 1.37},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000445',
#     'name': 'fruit seed number',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.49}},
#   {'source': {'id': 'CO_336:0000238',
#     'name': 'Seed weight',
#     'x': 1,
#     'y': 1.38},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000181',
#     'name': 'seed weight',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.55}},
#   {'source': {'id': 'CO_336:0000239',
#     'name': 'Cercospora Leaf spot',
#     'x': 1,
#     'y': 1.39},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002702',
#     'name': 'cercospora leaf spot resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.29}},
#   {'source': {'id': 'CO_331:0000034',
#     'name': 'Abaxial Leaf Vein Pigmentation',
#     'x': 2,
#     'y': 4.42},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000822',
#     'name': 'leaf midvein morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.87}},
#   {'source': {'id': 'CO_331:0000439',
#     'name': 'Alcidodes sp. damage',
#     'x': 2,
#     'y': 4.43},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000261',
#     'name': 'insect damage resistance',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000164',
#     'x': 0,
#     'y': 2.45}},
#   {'source': {'id': 'CO_331:0000428',
#     'name': 'Amylose content',
#     'x': 2,
#     'y': 4.44},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000196',
#     'name': 'amylose content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 2.96}},
#   {'source': {'id': 'CO_331:0000433',
#     'name': 'Anthocyanin content',
#     'x': 2,
#     'y': 4.45},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000281',
#     'name': 'metabolite content trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.1}},
#   {'source': {'id': 'CO_331:0000429',
#     'name': 'Asparagine content',
#     'x': 2,
#     'y': 4.46},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002673',
#     'name': 'amino acid content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 2.94}},
#   {'source': {'id': 'CO_331:0000308',
#     'name': 'Average commercial root weight',
#     'x': 2,
#     'y': 4.47},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0001041',
#     'name': 'root yield',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000371',
#     'x': 0,
#     'y': 3.56}},
#   {'source': {'id': 'CO_331:0000109',
#     'name': 'Beta-carotene content',
#     'x': 2,
#     'y': 4.48},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002695',
#     'name': 'beta-carotene content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 0.13}},
#   {'source': {'id': 'CO_331:0000311',
#     'name': 'Biomass yield',
#     'x': 2,
#     'y': 4.49},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0001041',
#     'name': 'root yield',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000371',
#     'x': 0,
#     'y': 3.56}},
#   {'source': {'id': 'CO_331:0000281',
#     'name': 'Calcium content',
#     'x': 2,
#     'y': 4.5},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0006047',
#     'name': 'calcium concentration',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.0}},
#   {'source': {'id': 'CO_331:0000133',
#     'name': 'Color of boiled roots',
#     'x': 2,
#     'y': 4.51},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000065',
#     'name': 'root color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.37}},
#   {'source': {'id': 'CO_331:0000437',
#     'name': 'Color of leave',
#     'x': 2,
#     'y': 4.52},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000326',
#     'name': 'leaf color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.78}},
#   {'source': {'id': 'CO_331:0000337',
#     'name': 'Color of stigma',
#     'x': 2,
#     'y': 4.53},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000185',
#     'name': 'stigma color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.86}},
#   {'source': {'id': 'CO_331:0000338',
#     'name': 'Color of style',
#     'x': 2,
#     'y': 4.54},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000676',
#     'name': 'style color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.89}},
#   {'source': {'id': 'CO_331:0000346',
#     'name': 'Consistency of boiled storage root',
#     'x': 2,
#     'y': 4.55},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0001042',
#     'name': 'root quality trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.81}},
#   {'source': {'id': 'CO_331:0000430',
#     'name': 'Cyanidin content',
#     'x': 2,
#     'y': 4.56},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000465',
#     'name': 'mineral and ion content related trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.11}},
#   {'source': {'id': 'CO_331:0000417',
#     'name': 'Deep of eyes of roots',
#     'x': 2,
#     'y': 4.57},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000843',
#     'name': 'portion of plant tissue morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.33}},
#   {'source': {'id': 'CO_331:0000064',
#     'name': 'Distribution of Secondary Flesh color',
#     'x': 2,
#     'y': 4.58},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000065',
#     'name': 'root color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.37}},
#   {'source': {'id': 'CO_331:0000130',
#     'name': 'Fiber content',
#     'x': 2,
#     'y': 4.6},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002642',
#     'name': 'dietary fiber related trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.69}},
#   {'source': {'id': 'CO_331:0000256',
#     'name': 'Fiber cooked',
#     'x': 2,
#     'y': 4.61},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0001042',
#     'name': 'root quality trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000597',
#     'x': 0,
#     'y': 3.81}},
#   {'source': {'id': 'CO_331:0000416',
#     'name': 'Flesh Color (anthocyanins)',
#     'x': 2,
#     'y': 4.62},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000065',
#     'name': 'root color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.37}},
#   {'source': {'id': 'CO_331:0000415',
#     'name': 'Flesh Color (carotenoids)',
#     'x': 2,
#     'y': 4.63},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000065',
#     'name': 'root color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 1.37}},
#   {'source': {'id': 'CO_331:0000046',
#     'name': 'Flower color',
#     'x': 2,
#     'y': 4.64},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000537',
#     'name': 'flower color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.38}},
#   {'source': {'id': 'CO_331:0000329',
#     'name': 'Flower size',
#     'x': 2,
#     'y': 4.65},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000499',
#     'name': 'flower morphology trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.39}},
#   {'source': {'id': 'CO_331:0000328',
#     'name': 'Flowering habit',
#     'x': 2,
#     'y': 4.66},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0002736',
#     'name': 'flower number trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.4}},
#   {'source': {'id': 'CO_331:0000312',
#     'name': 'Foliage total yield',
#     'x': 2,
#     'y': 4.67},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000870',
#     'name': 'leaf yield trait',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000371',
#     'x': 0,
#     'y': 3.53}},
#   {'source': {'id': 'CO_331:0000118',
#     'name': 'Fructose content',
#     'x': 2,
#     'y': 4.68},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0006005',
#     'name': 'fructose content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.04}},
#   {'source': {'id': 'CO_331:0000019',
#     'name': 'General Outline of the Leaf',
#     'x': 2,
#     'y': 4.69},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000492',
#     'name': 'leaf shape',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.92}},
#   {'source': {'id': 'CO_331:0000121',
#     'name': 'Glucose content',
#     'x': 2,
#     'y': 4.7},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000300',
#     'name': 'glucose content',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000277',
#     'x': 0,
#     'y': 3.05}},
#   {'source': {'id': 'CO_331:0000085',
#     'name': 'Harvest index',
#     'x': 2,
#     'y': 4.71},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000128',
#     'name': 'harvest index',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000371',
#     'x': 0,
#     'y': 3.52}},
#   {'source': {'id': 'CO_331:0000040',
#     'name': 'Immature Leaf Color',
#     'x': 2,
#     'y': 4.72},
#    'target': {'id': 'http://purl.obolibrary.org/obo/TO_0000326',
#     'name': 'leaf color',
#     'type': 'http://purl.obolibrary.org/obo/TO_0000017',
#     'x': 0,
#     'y': 0.78}},
# ...
#   {'id': 'CO_339:0000030', 'name': 'Cold tolerance', 'x': 1, 'y': 1.86},
#   {'id': 'CO_339:0000057', 'name': 'Drought tolerance', 'x': 1, 'y': 1.87},
#   {'id': 'CO_339:0000075', 'name': 'Heat tolerance', 'x': 1, 'y': 1.88},
#   {'id': 'CO_339:0000081', 'name': 'Herbicide tolerance', 'x': 1, 'y': 1.89},
#   {'id': 'CO_339:0000018',
#    'name': 'Boron toxicity tolerance',
#    'x': 1,
#    'y': 1.9},
#   {'id': 'CO_339:0000189',
#    'name': 'Water logging tolerance',
#    'x': 1,
#    'y': 1.91},
#   {'id': 'CO_339:0000135', 'name': 'Pod weight', 'x': 1, 'y': 1.92},
#   {'id': 'CO_339:0000126', 'name': 'Pod dehiscence', 'x': 1, 'y': 1.93},
#   {'id': 'CO_339:0000132', 'name': 'Pod shedding', 'x': 1, 'y': 1.94},
#   {'id': 'CO_339:0000159', 'name': 'Seed diameter', 'x': 1, 'y': 1.95},
#   {'id': 'CO_339:0000162', 'name': 'Grain protein content', 'x': 1, 'y': 1.96},
#   {'id': 'CO_339:0000165', 'name': 'Seed yield per plant', 'x': 1, 'y': 1.97},
#   {'id': 'CO_339:0000168', 'name': 'Seed yield per area', 'x': 1, 'y': 1.98},
#   {'id': 'CO_339:0000171', 'name': 'Chlorophyll content', 'x': 1, 'y': 1.99},
#   {'id': 'CO_339:0000180', 'name': 'Stomatal conductance', 'x': 1, 'y': 2.0},
#   {'id': 'CO_339:0000141',
#    'name': 'Primary branches number',
#    'x': 1,
#    'y': 2.01},
#   {'id': 'CO_339:0000156',
#    'name': 'Secondary branches number',
#    'x': 1,
#    'y': 2.02},
#   {'id': 'CO_339:0000183',
#    'name': 'Tertiary branches number',
#    'x': 1,
#    'y': 2.03},
#   {'id': 'CO_339:0000060', 'name': 'Early growth vigour', 'x': 1, 'y': 2.04},
#   {'id': 'CO_339:0000192', 'name': 'Winter survival', 'x': 1, 'y': 2.05},
#   {'id': 'CO_334:0000276', 'name': 'Abscisic Acid Content', 'x': 2, 'y': 6.18},
#   {'id': 'CO_334:0000277', 'name': 'Amylopectin Content', 'x': 2, 'y': 6.19},
#   {'id': 'CO_334:0000278',
#    'name': 'Amylose Amylopectin Ratio',
#    'x': 2,
#    'y': 6.2},
#   {'id': 'CO_334:0000279', 'name': 'Amylose Content', 'x': 2, 'y': 6.21},
#   {'id': 'CO_334:0000280', 'name': 'Anther Color', 'x': 2, 'y': 6.22},
#   {'id': 'CO_334:0000281',
#    'name': 'Anthocyanin Pigmentation',
#    'x': 2,
#    'y': 6.23},
#   {'id': 'CO_334:0000282', 'name': 'Apical Branching', 'x': 2, 'y': 6.24},
#   {'id': 'CO_334:0000283', 'name': 'Apical Pubescence', 'x': 2, 'y': 6.25},
#   {'id': 'CO_334:0000284', 'name': 'Ascorbic Acid', 'x': 2, 'y': 6.26},
#   {'id': 'CO_334:0000285', 'name': 'Ash Content', 'x': 2, 'y': 6.27},
#   {'id': 'CO_334:0000287', 'name': 'B crypto activity', 'x': 2, 'y': 6.28},
#   {'id': 'CO_334:0000288',
#    'name': 'Bemesia tabaci nymphs black',
#    'x': 2,
#    'y': 6.29},
#   {'id': 'CO_334:0000289',
#    'name': 'Bemesia tabaci nymphs severity',
#    'x': 2,
#    'y': 6.3},
#   {'id': 'CO_334:0000290',
#    'name': 'Bemesia tabaci nymphs yellow',
#    'x': 2,
#    'y': 6.31},
#   {'id': 'CO_334:0000291', 'name': 'Beta carotene', 'x': 2, 'y': 6.32},
#   {'id': 'CO_334:0000292',
#    'name': 'Beta Carotenoid Retention',
#    'x': 2,
#    'y': 6.33},
#   {'id': 'CO_334:0000293', 'name': 'Branch height', 'x': 2, 'y': 6.34},
#   {'id': 'CO_334:0000294', 'name': 'Branching Angle', 'x': 2, 'y': 6.35},
#   {'id': 'CO_334:0000295', 'name': 'Branching habit', 'x': 2, 'y': 6.36},
#   {'id': 'CO_334:0000296', 'name': 'Branching Levels', 'x': 2, 'y': 6.37},
#   {'id': 'CO_334:0000297', 'name': 'Carotenoid content', 'x': 2, 'y': 6.38},
#   {'id': 'CO_334:0000298', 'name': 'Caruncle Color', 'x': 2, 'y': 6.39},
#   {'id': 'CO_334:0000038',
#    'name': 'Cassava anthracnose disease incidence',
#    'x': 2,
#    'y': 6.4},
#   {'id': 'CO_334:0000032',
#    'name': 'Cassava anthracnose disease severity',
#    'x': 2,
#    'y': 6.41},
#   {'id': 'CO_334:0000037',
#    'name': 'Cassava bacterial blight incidence',
#    'x': 2,
#    'y': 6.42},
#   {'id': 'CO_334:0000031',
#    'name': 'Cassava bacterial blight severity',
#    'x': 2,
#    'y': 6.43},
#   {'id': 'CO_334:0000040',
#    'name': 'Cassava brown streak disease leaf incidence',
#    'x': 2,
#    'y': 6.44},
#   {'id': 'CO_334:0000036',
#    'name': 'Cassava brown streak disease leaf severity',
#    'x': 2,
#    'y': 6.45},
#   {'id': 'CO_334:0000089',
#    'name': 'Cassava brown streak disease root incidence',
#    'x': 2,
#    'y': 6.46},
#   {'id': 'CO_334:0000090',
#    'name': 'Cassava brown streak disease root severity',
#    'x': 2,
#    'y': 6.47},
#   {'id': 'CO_334:0000122',
#    'name': 'Cassava green mite incidence',
#    'x': 2,
#    'y': 6.48},
#   {'id': 'CO_334:0000033',
#    'name': 'Cassava green mite severity',
#    'x': 2,
#    'y': 6.49},
#   {'id': 'CO_334:0000339',
#    'name': 'Cassava Mealy Bug Incidence',
#    'x': 2,
#    'y': 6.5},
#   {'id': 'CO_334:0000340',
#    'name': 'Cassava Mealy Bug Severity',
#    'x': 2,
#    'y': 6.51},
#   {'id': 'CO_334:0000039',
#    'name': 'Cassava mosaic disease incidence',
#    'x': 2,
#    'y': 6.52},
#   {'id': 'CO_334:0000035',
#    'name': 'Cassava mosaic disease severity',
#    'x': 2,
#    'y': 6.53},
#   {'id': 'CO_334:0000353', 'name': 'Central Leaf Shape', 'x': 2, 'y': 6.54},
#   {'id': 'CO_334:0000354', 'name': 'Cis 9 activity', 'x': 2, 'y': 6.55},
#   {'id': 'CO_334:0000355',
#    'name': 'Color Of Boiled Tuberous Roots',
#    'x': 2,
#    'y': 6.56},
#   {'id': 'CO_334:0000356', 'name': 'Days to 50% anthesis', 'x': 2, 'y': 6.57},
#   {'id': 'CO_334:0000357', 'name': 'Days to 50% branching', 'x': 2, 'y': 6.58},
#   {'id': 'CO_334:0000358',
#    'name': 'Days to first anthesis',
#    'x': 2,
#    'y': 6.59},
#   {'id': 'CO_334:0000359',
#    'name': 'Days to first inflorescence',
#    'x': 2,
#    'y': 6.6},
#   {'id': 'CO_334:0000360', 'name': 'Disc Color', 'x': 2, 'y': 6.61},
#   {'id': 'CO_334:0000361', 'name': 'Ease of Harvest', 'x': 2, 'y': 6.62},
#   {'id': 'CO_334:0000362',
#    'name': 'Ease Of Peeling Root Cortex',
#    'x': 2,
#    'y': 6.63},
#   {'id': 'CO_334:0000364', 'name': 'Female flower number', 'x': 2, 'y': 6.64},
#   {'id': 'CO_334:0000365', 'name': 'Female Stamenoids', 'x': 2, 'y': 6.65},
#   {'id': 'CO_334:0000366', 'name': 'Fibre Content', 'x': 2, 'y': 6.66},
#   {'id': 'CO_334:0000367', 'name': 'Flowering', 'x': 2, 'y': 6.67},
#   {'id': 'CO_334:0000369', 'name': 'Fresh Shoot Weight', 'x': 2, 'y': 6.68},
#   {'id': 'CO_334:0000370', 'name': 'Frog Skin Disease', 'x': 2, 'y': 6.69},
#   {'id': 'CO_334:0000371', 'name': 'Fruit Exocarp Texture', 'x': 2, 'y': 6.7},
#   {'id': 'CO_334:0000372', 'name': 'Fruit set presence', 'x': 2, 'y': 6.71},
#   {'id': 'CO_334:0000373', 'name': 'Fufu Content', 'x': 2, 'y': 6.72},
#   {'id': 'CO_334:0000374', 'name': 'Gari Content', 'x': 2, 'y': 6.73},
#   {'id': 'CO_334:0000378', 'name': 'Gari fibre', 'x': 2, 'y': 6.74},
#   {'id': 'CO_334:0000379', 'name': 'Gari sampled weight', 'x': 2, 'y': 6.75},
#   {'id': 'CO_334:0000375', 'name': 'Gari shaft weight', 'x': 2, 'y': 6.76},
#   {'id': 'CO_334:0000380', 'name': 'Gari starch', 'x': 2, 'y': 6.77},
#   {'id': 'CO_334:0000381', 'name': 'Gari taste', 'x': 2, 'y': 6.78},
#   {'id': 'CO_334:0000376',
#    'name': 'Gari weight after drying',
#    'x': 2,
#    'y': 6.79},
#   {'id': 'CO_334:0000377',
#    'name': 'Gari weight after grinding',
#    'x': 2,
#    'y': 6.8},
#   {'id': 'CO_334:0000382', 'name': 'Hairiness', 'x': 2, 'y': 6.81},
#   {'id': 'CO_334:0000386', 'name': 'Initial Vigor', 'x': 2, 'y': 6.82},
#   {'id': 'CO_334:0000387', 'name': 'Iron Content', 'x': 2, 'y': 6.83},
#   {'id': 'CO_334:0000388', 'name': 'Lafun Content', 'x': 2, 'y': 6.84},
#   {'id': 'CO_334:0000389', 'name': 'Leaf color', 'x': 2, 'y': 6.85},
#   {'id': 'CO_334:0000390', 'name': 'Leaf Life span', 'x': 2, 'y': 6.86},
#   {'id': 'CO_334:0000391', 'name': 'Leaf lobe length', 'x': 2, 'y': 6.87},
#   {'id': 'CO_334:0000392', 'name': 'Leaf lobe margin', 'x': 2, 'y': 6.88},
#   {'id': 'CO_334:0000393', 'name': 'Leaf Lobe Position', 'x': 2, 'y': 6.89},
#   {'id': 'CO_334:0000394', 'name': 'Leaf lobe width', 'x': 2, 'y': 6.9},
#   {'id': 'CO_334:0000395', 'name': 'Leaf Lobes Number', 'x': 2, 'y': 6.91},
#   {'id': 'CO_334:0000396', 'name': 'Leaf Retention', 'x': 2, 'y': 6.92},
#   {'id': 'CO_334:0000397', 'name': 'Leaf scar distance', 'x': 2, 'y': 6.93},
#   {'id': 'CO_334:0000398', 'name': 'Leaf scar height', 'x': 2, 'y': 6.94},
#   {'id': 'CO_334:0000399', 'name': 'Leaf scar number', 'x': 2, 'y': 6.95},
#   {'id': 'CO_334:0000400', 'name': 'Leaf Scar Prominence', 'x': 2, 'y': 6.96},
#   {'id': 'CO_334:0000401', 'name': 'Leaf Vein Color', 'x': 2, 'y': 6.97},
#   {'id': 'CO_334:0000402', 'name': 'Leaf weight', 'x': 2, 'y': 6.98},
#   {'id': 'CO_334:0000403', 'name': 'Male flower number', 'x': 2, 'y': 6.99},
#   {'id': 'CO_334:0000404', 'name': 'Male Sterile', 'x': 2, 'y': 7.0},
#   {'id': 'CO_334:0000405',
#    'name': 'Marketable root number',
#    'x': 2,
#    'y': 7.01},
#   {'id': 'CO_334:0000406',
#    'name': 'Marketable root weight',
#    'x': 2,
#    'y': 7.02},
#   {'id': 'CO_334:0000407', 'name': 'Moisture Content', 'x': 2, 'y': 7.03},
#   {'id': 'CO_334:0000408',
#    'name': 'Non marketable root number',
#    'x': 2,
#    'y': 7.04},
#   {'id': 'CO_334:0000409',
#    'name': 'Non marketable root weight',
#    'x': 2,
#    'y': 7.05},
#   {'id': 'CO_334:0000410',
#    'name': 'Number of Bemesia tabaci adult',
#    'x': 2,
#    'y': 7.06},
#   {'id': 'CO_334:0000411',
#    'name': 'Number of Bemesia tabaci nymphs',
#    'x': 2,
#    'y': 7.07},
#   {'id': 'CO_334:0000412',
#    'name': 'Number of flowering stalks',
#    'x': 2,
#    'y': 7.08},
#   {'id': 'CO_334:0000413', 'name': 'Number of forks', 'x': 2, 'y': 7.09},
#   {'id': 'CO_334:0000414', 'name': 'Number of fruits', 'x': 2, 'y': 7.1},
#   {'id': 'CO_334:0000415', 'name': 'Number of fruitset', 'x': 2, 'y': 7.11},
#   {'id': 'CO_334:0000417', 'name': 'Number of rotten stem', 'x': 2, 'y': 7.12},
#   {'id': 'CO_334:0000419', 'name': 'Number of stakes', 'x': 2, 'y': 7.13},
#   {'id': 'CO_334:0000420',
#    'name': 'Number of terminal branches with inflorescence',
#    'x': 2,
#    'y': 7.14},
#   {'id': 'CO_334:0000421', 'name': 'Ovary Color', 'x': 2, 'y': 7.15},
#   {'id': 'CO_334:0000422', 'name': 'Peel weight', 'x': 2, 'y': 7.16},
#   {'id': 'CO_334:0000427', 'name': 'Petiole Color', 'x': 2, 'y': 7.17},
#   {'id': 'CO_334:0000428',
#    'name': 'Petiole Insertion Angle',
#    'x': 2,
#    'y': 7.18},
#   {'id': 'CO_334:0000429', 'name': 'Petiole length', 'x': 2, 'y': 7.19},
#   {'id': 'CO_334:0000430', 'name': 'Petiole orientation', 'x': 2, 'y': 7.2},
#   {'id': 'CO_334:0000431', 'name': 'Plant Architecture', 'x': 2, 'y': 7.21},
#   {'id': 'CO_334:0000432', 'name': 'Plant Height', 'x': 2, 'y': 7.22},
#   {'id': 'CO_334:0000433', 'name': 'Plant shape', 'x': 2, 'y': 7.23},
#   {'id': 'CO_334:0000436', 'name': 'Ploidy', 'x': 2, 'y': 7.24},
#   {'id': 'CO_334:0000437', 'name': 'Poundability', 'x': 2, 'y': 7.25},
#   {'id': 'CO_334:0000438', 'name': 'Presence of pollen', 'x': 2, 'y': 7.26},
#   {'id': 'CO_334:0000439',
#    'name': 'Proportion of female flower',
#    'x': 2,
#    'y': 7.27},
#   {'id': 'CO_334:0000441',
#    'name': 'Proportion of plant with inflorescence',
#    'x': 2,
#    'y': 7.28},
#   {'id': 'CO_334:0000442', 'name': 'Protein Content', 'x': 2, 'y': 7.29},
#   {'id': 'CO_334:0000443',
#    'name': 'Red Spider Mite Incidence',
#    'x': 2,
#    'y': 7.3},
#   {'id': 'CO_334:0000444',
#    'name': 'Red Spider Mite Severity',
#    'x': 2,
#    'y': 7.31},
#   {'id': 'CO_334:0000446',
#    'name': 'Root constrictions number',
#    'x': 2,
#    'y': 7.32},
#   {'id': 'CO_334:0000447',
#    'name': 'Root Dry Matter Content',
#    'x': 2,
#    'y': 7.33},
#   {'id': 'CO_334:0000448', 'name': 'Root evaluation', 'x': 2, 'y': 7.34},
#   {'id': 'CO_334:0000450', 'name': 'Root length', 'x': 2, 'y': 7.35},
#   {'id': 'CO_334:0000451', 'name': 'Root Neck Length', 'x': 2, 'y': 7.36},
#   {'id': 'CO_334:0000452', 'name': 'Root Number', 'x': 2, 'y': 7.37},
#   {'id': 'CO_334:0000453', 'name': 'Root Position', 'x': 2, 'y': 7.38},
#   {'id': 'CO_334:0000454', 'name': 'Root Surface Color', 'x': 2, 'y': 7.39},
#   {'id': 'CO_334:0000455', 'name': 'Root Surface Texture', 'x': 2, 'y': 7.4},
#   {'id': 'CO_334:0000456', 'name': 'Root Yield', 'x': 2, 'y': 7.41},
#   {'id': 'CO_334:0000457', 'name': 'Rotted Storage Roots', 'x': 2, 'y': 7.42},
#   {'id': 'CO_334:0000458',
#    'name': 'Rotten root proportion',
#    'x': 2,
#    'y': 7.43},
#   {'id': 'CO_334:0000459', 'name': 'Seed Color', 'x': 2, 'y': 7.44},
#   {'id': 'CO_334:0000460', 'name': 'Seedling number', 'x': 2, 'y': 7.45},
#   {'id': 'CO_334:0000462', 'name': 'Sepal Color', 'x': 2, 'y': 7.46},
#   {'id': 'CO_334:0000463', 'name': 'Sooty Mould', 'x': 2, 'y': 7.47},
#   {'id': 'CO_334:0000464',
#    'name': 'Spiraling Whitefly Incidence',
#    'x': 2,
#    'y': 7.48},
#   {'id': 'CO_334:0000465',
#    'name': 'Spiraling Whitefly Severity',
#    'x': 2,
#    'y': 7.49},
#   {'id': 'CO_334:0000466', 'name': 'Sprout count', 'x': 2, 'y': 7.5},
#   {'id': 'CO_334:0000472', 'name': 'Sprouting', 'x': 2, 'y': 7.51},
#   {'id': 'CO_334:0000473', 'name': 'Stalk length', 'x': 2, 'y': 7.52},
#   {'id': 'CO_334:0000474', 'name': 'Starch Content', 'x': 2, 'y': 7.53},
#   {'id': 'CO_334:0000475', 'name': 'Stem Color', 'x': 2, 'y': 7.54},
#   {'id': 'CO_334:0000476', 'name': 'Stem cortex color', 'x': 2, 'y': 7.55},
#   {'id': 'CO_334:0000477', 'name': 'Stem epidermis color', 'x': 2, 'y': 7.56},
#   {'id': 'CO_334:0000478', 'name': 'Stem height', 'x': 2, 'y': 7.57},
#   {'id': 'CO_334:0000479', 'name': 'Stem number', 'x': 2, 'y': 7.58},
#   {'id': 'CO_334:0000480', 'name': 'Stem weight', 'x': 2, 'y': 7.59},
#   {'id': 'CO_334:0000481', 'name': 'Stigma Color', 'x': 2, 'y': 7.6},
#   {'id': 'CO_334:0000482', 'name': 'Stipule margin', 'x': 2, 'y': 7.61},
#   {'id': 'CO_334:0000483', 'name': 'Stipules Length', 'x': 2, 'y': 7.62},
#   {'id': 'CO_334:0000484', 'name': 'Stock weight', 'x': 2, 'y': 7.63},
#   {'id': 'CO_334:0000485',
#    'name': 'Storage Root Constrictions',
#    'x': 2,
#    'y': 7.64},
#   {'id': 'CO_334:0000486',
#    'name': 'Storage Root Cortex Color',
#    'x': 2,
#    'y': 7.65},
#   {'id': 'CO_334:0000487', 'name': 'Storage Root Diameter', 'x': 2, 'y': 7.66},
#   {'id': 'CO_334:0000488', 'name': 'Storage Root Peduncle', 'x': 2, 'y': 7.67},
#   {'id': 'CO_334:0000489',
#    'name': 'Storage Root Periderm Color',
#    'x': 2,
#    'y': 7.68},
#   {'id': 'CO_334:0000490',
#    'name': 'Storage Root Pulp Color',
#    'x': 2,
#    'y': 7.69},
#   {'id': 'CO_334:0000491', 'name': 'Storage Root Shape', 'x': 2, 'y': 7.7},
#   {'id': 'CO_334:0000492', 'name': 'Storage Root Size', 'x': 2, 'y': 7.71},
#   {'id': 'CO_334:0000493', 'name': 'Storage root weight', 'x': 2, 'y': 7.72},
#   {'id': 'CO_334:0000494', 'name': 'Stump weight', 'x': 2, 'y': 7.73},
#   {'id': 'CO_334:0000495', 'name': 'Sugar Content', 'x': 2, 'y': 7.74},
#   {'id': 'CO_334:0000497', 'name': 'Swelling capacity', 'x': 2, 'y': 7.75},
#   {'id': 'CO_334:0000498', 'name': 'Taste Of Boiled Roots', 'x': 2, 'y': 7.76},
#   {'id': 'CO_334:0000499', 'name': 'Tip shoot weight', 'x': 2, 'y': 7.77},
#   {'id': 'CO_334:0000500',
#    'name': 'Total Carotenoid Retention',
#    'x': 2,
#    'y': 7.78},
#   {'id': 'CO_334:0000501', 'name': 'Trans-9 activity', 'x': 2, 'y': 7.79},
#   {'id': 'CO_334:0000502',
#    'name': 'Tuberous root cyanide content',
#    'x': 2,
#    'y': 7.8},
#   {'id': 'CO_334:0000503', 'name': 'Typhlodromalus aripo', 'x': 2, 'y': 7.81},
#   {'id': 'CO_334:0000504',
#    'name': 'Weight of mashed cassava cake',
#    'x': 2,
#    'y': 7.82},
#   {'id': 'CO_334:0000505',
#    'name': 'Young Stem Growth Habit',
#    'x': 2,
#    'y': 7.83},
#   {'id': 'CO_334:0000506', 'name': 'Young Stem Pubescence', 'x': 2, 'y': 7.84},
#   {'id': 'CO_334:0000507', 'name': 'Zinc Content', 'x': 2, 'y': 7.85},
#   {'id': 'CO_320:0000483', 'name': 'anther colour', 'x': 1, 'y': 2.06},
#   {'id': 'CO_320:0000150', 'name': 'anther length', 'x': 1, 'y': 2.07},
#   {'id': 'CO_320:0000484',
#    'name': 'anthocyanin below apiculus',
#    'x': 1,
#    'y': 2.08},
#   {'id': 'CO_320:0000485', 'name': 'apiculus anthocyanin', 'x': 1, 'y': 2.09},
#   {'id': 'CO_320:0000487', 'name': 'auricle anthocyanin', 'x': 1, 'y': 2.1},
#   {'id': 'CO_320:0000011', 'name': 'leaf length', 'x': 1, 'y': 2.11},
#   {'id': 'CO_320:0000037', 'name': 'apiculus color', 'x': 1, 'y': 2.12},
#   {'id': 'CO_320:0000486', 'name': 'apiculus shape', 'x': 1, 'y': 2.13},
#   {'id': 'CO_320:0000029', 'name': 'auricle color', 'x': 1, 'y': 2.14},
#   {'id': 'CO_320:0000036', 'name': 'awn color', 'x': 1, 'y': 2.15},
#   ...]}
